# %%
# Task 1
# Recursion
def fac_fun(num):

    if num == 0:
        return 1
    # if num == 1:
    #     return 1
    return num * fac_fun(num - 1)
fac_fun(5)
# Out:
# 120

# %%
# Task 2
# Prime Numbers
def is_prime(num):
    for i in range(2,num):
        if num % i == 0:
            return False
    return True
print(is_prime(3))
print(is_prime(12))
# Out:
# True
# False

# %%
# Task 3
# Common Dividors 

def dividors(num1:int, num2:int):

    mn = min(num1,num2) # ? mn + 1 ?
    common_div = []
    for i in range(1,mn + 1):
        if num1 % i == 0 and num2 % i == 0 :
            common_div.append(i)
    return common_div
dividors(10,20)
# Out:
# [1, 2, 5, 10]

# %%
# Task 4
# Generating Password 
import random
def gen_pas(length:int):

    char = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password = ""
    for _ in range(length): # _ not intersted in i but what it represent 
        password += random.choice(char)

    return password
gen_pas(5)
# Out:
# '@Sbl&'

# %%
# Task 5
# Extract the Unique Words
words = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]

def unique_words(words):
    unique_word = set(words)
    counts  = {word: 0 for word in unique_word}
    for i in unique_word:  # o(n)
        for j in words:   #o(n)
            if i in  j :
                counts[i] +=1
    return counts,unique_word

unique_words(words)
# Out:
# ({'Welcome': 1, 'Ali': 4, 'Hi': 2, 'No': 3}, {'Ali', 'Hi', 'No', 'Welcome'})

# %%
# Task 6
# ChatBot
 
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}

def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])

def chatbot():
    print("chatbot: HI How I Can Assist You Today?")
    while True:
        user_input = input("User:    ".lower)
        response = get_response(user_input)
        print("chatbot: ",response)
        if user_input == "goodbye":
            break
if __name__ == "__main__":
    chatbot()
# Out:
# chatbot: HI How I Can Assist You Today?
# chatbot:  Hello!
# chatbot:  I'm doing well, thank you!
# chatbot:  Farewell!

# %% [markdown]
# ### OOP

# %%
class StudentInfo:

    name = "Mohamed"
    age = "25"
    gpa = "3.1"
    course = "ml"

    def get_info(self):
        return print(self)
    
s1 = StudentInfo()
# s1.name = "abdeen"
# s1.name
print(s1)
print(s1.get_info())
# Out:
# <__main__.StudentInfo object at 0x0000023D72E6E110>
# <__main__.StudentInfo object at 0x0000023D72E6E110>
# None

# %%
class StudentInfo:
    def __init__(self,name,age,gpa,course):
        self.name = name
        self.age  = age 
        self.gpa = gpa
        self.course = course

    def get_info(self):
        return f"my name is {self.name}, and my age is {self.age}"


s1 = StudentInfo("Mohamed",25,3.1,"ml")
s1.get_info()
# Out:
# 'my name is Mohamed, and my age is 25'

# %%
 
class PasswordGenerator:
    def __init__(self):
        self.length = 8
        self.characters = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    def generate_password(self,length):
        password = ""
        num_of_chars = len(self.characters)
       
        for _ in range(self.length):
            rand_index = random.randrange(0, num_of_chars)
            password += self.characters[rand_index]
       
        return password
 
# Usage example
if __name__ == "__main__":
   
    # password_length = 8  # You can change this to your desired length
    generator = PasswordGenerator()
    random_password = generator.generate_password(8)
    print(random_password)
# Out:
# *cou0DzS
