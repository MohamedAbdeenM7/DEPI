# %% [markdown]
# # 1. Reverse Words

# %%
def reverseWords(s:str):
    words = s.split()      
    words.reverse()        
    return " ".join(words)

reverseWords("Mohamed Abdeen Mostafa")
# Out:
# 'Mostafa Abdeen Mohamed'

# %% [markdown]
# # 2. Product of Array Except Self

# %%
def productExceptSelf(nums):
    
    n = len(nums)
    answer = [1] * n

    # Prefix products
    prefix = 1
    for i in range(n):
        answer[i] = prefix
        prefix *= nums[i]

    # Suffix products
    suffix = 1
    for i in range(n - 1, -1, -1):
        answer[i] *= suffix
        suffix *= nums[i]

    return answer

# %%
lst = [1,2,3,4,5,6]
productExceptSelf(nums=lst)
# Out:
# [720, 360, 240, 180, 144, 120]
